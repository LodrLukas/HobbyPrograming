# %% [markdown]
# # Plnění plechovek pórkovou polévkou
# Představme si, že pracujeme pro mezinárodní firmu PolPór a máme za úkol naplnit plechovky pórkovou polévkou.
# Vždy dostaneme několik litrů polévky a tu musíme rozdělit do několika plechovek:
# - plechovky o velikosti 3 litrů
# - plechovky o velikosti 5 litrů
#
# Za úkol ale máme, rozdělit polévku <b>všechnu</b> a nebo <b>žádnou!!!</b>
# Plechovky jsou ve skladu, kam je cesta dlouhá a tak půjdeme pro dnešek jenom jednou, s tím, že vezmeme pouze jedno balení plechovek (Uvažujme libovolně velké balení plechovek, ovšem stejného druhu - tedy nekonečno 3 litrových nebo nekonečno 5 litrových plechovek).
#
# Abychom si zjednodušili práci a nemuseli vše ručně počítat, uděláme si program, který nám s tím pomuže a řekne nám, jaké balení vzít.

# %% [markdown]
# ### 1. Krok: Operátor % (Zbytek po dělení)
# Než začneme plnit plechovky, musíme zjistit, jestli nám v nich polévka nezbyde. K tomu v programování používáme operátor modulo %.
#
# Vysvětlení: 10 % 3 nám řekne, kolik polévky zbude, když 10 litrů rozdělíme do 3-litrových plechovek. (Zbytek je 1 litr). Pokud je zbytek 0, polévka je přesně rozdělená!

# %%
print( "10 % 3 = ", 10 % 3 )
print( " 8 % 2 = ", 8 % 2 )
print( " 5 % 7 = ", 5 % 7 )

# %% [markdown]
# ### 2. Krok: Funkce a podmínky
# Doplňte funkci tak, aby vracela text podle toho, do jakých plechovek se polévka vejde. Začněme s první možností - zda se vejde do 3L plechovek. Poté můžeme zkusit dopsat podmínky a dodělat to celé.

# %%
def zkontroluj_polevku(litru):
    # TODO: Pokud jde polévka rozdělit do 3L i 5L plechovek, vrať "Oboje"
    # TODO: Pokud jde jen do 3L, vrať "3 litrové"
    # TODO: Pokud jde jen do 5L, vrať "5 litrové"
    # TODO: Jinak vrať "Nelze rozdělit"
    
    if "???" == 0 :
        return "3 litrové"
    #elif ...
    else:
        return "Nelze rozdělit"

# Testování:
pocet = 9
print(zkontroluj_polevku(pocet))

# %% [markdown]
# ### 3. Krok: Finální program (Moduly a výpočet)
# V reálném světě chceme vědět, kolik těch plechovek budeme potřebovat. K tomu využijeme celočíselné dělení <b>//</b>. Upravte funkci tak, aby nevracela jen text, ale přímo vypočítala počet plechovek. Pokud polévka nejde rozdělit beze zbytku, program se omluví.
#
# Celočíselné dělení <b>//</b> funguje jako klasické dělení, akorát neukazuje zbytek za desetinnou čárkou.
# - 10 // 5 = 2
# - 6 // 5 = 1
# - 5 // 5 = 1
# - 4 // 5 = 0
#
# (Když používáme input(), píšeme vstup nahoru do okna, které se zobrazí po spuštění - ukáže se zpráva jako z terminálu, akorát je v oknu)

# %%
def napln_sklad(litru, velikost_plechovky):
    """
    Funkce zjistí, zda lze polévku rozdělit.
    Pokud ano, vrátí počet plechovek. Pokud ne, vrátí 0.
    """
    if "???":
        return "???"
    else:
        return 0

# --- HLAVNÍ ČÁST PROGRAMU ---
polevka = int(input("Zadej celkové množství polévky (litry): "))
typ = int(input("Jak velké plechovky jsi vzal ze skladu? (3 nebo 5): "))

pocet = napln_sklad(polevka, typ)
try:
    if pocet > 0:
        print(f"Skvělé! Naplníme přesně {pocet} plechovek o objemu {typ} litrů.")
    else:
        print(f"Bohužel, {polevka} litrů do {typ} litrových plechovek beze zbytku nerozdělíš!")
except TypeError:
    print("Hmmmm, něco je nejspíš špatně s hodnotami...")
