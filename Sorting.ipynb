# %% [markdown]
# ## Zjednodušení života v Minecraftu
#
# Znáš takový ten pocit, kdy máš v truhlách brutální bordel a pak se začneš proklínat, proč sis nestáhnul ten mód, který ti seřadí všechny předměty jedním klikem? Co takhle udělat kód, který by to za nás udělal...
#
# ### 1. Náhodné řazení (Bogo Sort) – "Gamba je vždy cesta"
#
# Tato metoda je spíše úkázka, že gamble se dá využít všude. Algoritmus vezme všechny věci, vyhodí je do vzduchu a doufá, že až dopadnou, budou náhodou seřazené.
#
# * **Princip:** Zamíchej seznam. Je seřazený? Ne? Zamíchej znovu!
# * **Složitost:** Tahle metoda může trvat věčnost (doslova).
#
# ```plaintext
# OPAKUJ:
#     ZAMÍCHEJ všechny předměty v truhle náhodně
#     POKUD jsou předměty SEŘAZENY:
#         STOP (máme hotovo!)
#     JINAK:
#         POKRAČUJ v opakování
#
# ```

# %%
import random

def bogo_sort(poklady):
    #TODO
    return poklady

truhla = [5, 2, 4, 1] # Zkoušej jen s malým počtem!
print(bogo_sort(truhla))

# %% [markdown]
# ### 2. Bubble Sort – "Bublinky jak v lávě"
#
# Tady už začínáme logicky. Větší (těžší) předměty "probublávají" na konec seznamu.
#
# * **Úkol:** Porovnej dva sousedy. Pokud je ten vlevo větší než ten vpravo, prohoď je. Opakuj, dokud nejsou všichni na svém místě.
# * **Složitost:** $O(n^2)$
#
# ```plaintext
# PRO každé patro v truhle (od prvního do posledního):
#     PRO každou dvojici sousedů vedle sebe:
#         POKUD levý předmět > pravý předmět:
#             PROHOĎ je mezi sebou
#     (Tímto se největší prvek dostal na konec jako bublina)
#
# ```

# %%
def bubble_sort(poklady):
    #TODO
    return poklady
truhla = []
print(bubble_sort(truhla))

# %% [markdown]
# ### 3. Insertion Sort – "Hráč karet"
#
# Představ si, že držíš v ruce karty a přijde ti nová. Najdeš jí správné místo a tam ji "vrazíš" (vložíš).
#
# * **Úkol:** Postupně bereme prvky a vkládáme je do už seřazené části vlevo.
#
# ```plaintext
# PRO každý předmět v truhle (začneme druhým v pořadí):
#     VEZMI tento předmět do ruky (říkejme mu "KLÍČ")
#     DÍVEJ SE na předměty vlevo od něj:
#         DOKUD je předmět vlevo větší než "KLÍČ":
#             POSUŇ ten předmět o jedno místo doprava
#         VLOŽ "KLÍČ" na volné místo
#
# ```

# %%
def insertion_sort(poklady):
    #TODO
    return poklady
truhla = []
print(insertion_sort(truhla))

# %% [markdown]
# ### 4. Selection Sort – "Hledač nejmenšího"
#
# Tenhle algoritmus je jako prohledávání truhly. Najdeš ten úplně nejmenší předmět a dáš ho na první místo. Pak najdeš druhý nejmenší...
#
# * **Úkol:** Najdi minimum v nezpracované části a vyměň ho s prvním prvkem této části.
#
# ```plaintext
# PRO každou pozici v truhle (od začátku do konce):
#     NAJDI v nevyřízené části truhly ten úplně NEJMENŠÍ předmět
#     VYMĚŇ tento nejmenší předmět s tím, který stojí na aktuální pozici
#
# ```

# %%
def selection_sort(poklady):
    #TODO
    return poklady
truhla = []
print(selection_sort(truhla))

# %% [markdown]
# ### 5. Merge Sort – "Rozděl a panuj"
#
# Tady už jde do tuhého. Merge sort je velmi rychlý. Rozdělí seznam na poloviny, ty seřadí a pak je spojí (merge) dohromady.
#
# * **Princip:** Rekurze. Krájíme seznam tak dlouho, až máme jednotlivé kousky, které pak složíme zpět jako puzzle.
#
# ```plaintext
# FUNKCE Seřaď(seznam):
#     POKUD má seznam jen 1 prvek:
#         VRAT ho (je už seřazený)
#
#     ROZDĚL seznam na levou a pravou polovinu
#     SEŘAĎ levou polovinu (zavolej tuhle funkci znovu)
#     SEŘAĎ pravou polovinu (zavolej tuhle funkci znovu)
#
#     SLUČ (Merge) obě seřazené poloviny dohromady tak,
#     aby výsledný seznam byl správně od nejmenšího po největší
#
# ```

# %%
def merge_sort(poklady):
    #TODO
    return poklady
truhla = []
print(merge_sort(truhla))

# %% [markdown]
# ### 6. Quick Sort – "Mistr Pivot" (Finále)
#
# Nejpoužívanější algoritmus. Vybereš si jednoho "vůdce" (pivot) a ostatní rozdělíš na dvě skupiny: menší než vůdce a větší než vůdce.
#
# * **Úkol:** Zvol pivot (třeba poslední prvek). Všechny menší dej vlevo, všechny větší vpravo. Zopakuj pro obě strany.
# * **Složitost:** Průměrně $O(n \log n)$.
#
# ```plaintext
# FUNKCE QuickSort(seznam):
#     POKUD je seznam prázdný nebo má 1 prvek:
#         VRAT seznam
#
#     ZVOL si jeden prvek jako PIVOTA (např. ten uprostřed)
#     VYTVOŘ skupinu "MENŠÍ" (vše, co je menší než pivot)
#     VYTVOŘ skupinu "STEJNÉ" (vše, co je stejné jako pivot)
#     VYTVOŘ skupinu "VĚTŠÍ" (vše, co je větší než pivot)
#
#     VÝSLEDEK = QuickSort(MENŠÍ) + STEJNÉ + QuickSort(VĚTŠÍ)
#     VRAT VÝSLEDEK
#
# ```

# %%
def quick_sort(poklady):
    #TODO
    return poklady
truhla = []
print(quick_sort(truhla))

# %% [markdown]
# ### Závěrečná výzva: "Velký test rychlosti"
#
# Vygenerujeme seznam 1000 náhodných čísel a zkusíme je seřadit pomocí Bubble Sortu a pak pomocí Quick Sortu.
#
# **Otázka:**
# "Který algoritmus stihl seřadit 1000 itemů dřív?"
